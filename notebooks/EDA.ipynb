# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/Users/nadianesib/Desktop/week 6/data/data.csv') #load dataset.

# %%
data
# Out:
#               TransactionId         BatchId       AccountId  \
# 0       TransactionId_76871   BatchId_36123  AccountId_3957
# 1       TransactionId_73770   BatchId_15642  AccountId_4841
# 2       TransactionId_26203   BatchId_53941  AccountId_4229
# 3         TransactionId_380  BatchId_102363   AccountId_648
# 4       TransactionId_28195   BatchId_38780  AccountId_4841
# ...                     ...             ...             ...
# 95657   TransactionId_89881   BatchId_96668  AccountId_4841
# 95658   TransactionId_91597    BatchId_3503  AccountId_3439
# 95659   TransactionId_82501  BatchId_118602  AccountId_4841
# 95660  TransactionId_136354   BatchId_70924  AccountId_1346
# 95661   TransactionId_35670   BatchId_29317  AccountId_4841
#
#             SubscriptionId       CustomerId CurrencyCode  CountryCode  \
# 0       SubscriptionId_887  CustomerId_4406          UGX          256
# 1      SubscriptionId_3829  CustomerId_4406          UGX          256
# ...

# %% [markdown]
# # Overview of the data

# %%
#Understand the structure of the dataset, including the number of rows, columns, and data types.

# %%
# View the first few rows of the DataFrame
data.head(50)
# Out:
#            TransactionId         BatchId       AccountId       SubscriptionId  \
# 0    TransactionId_76871   BatchId_36123  AccountId_3957   SubscriptionId_887
# 1    TransactionId_73770   BatchId_15642  AccountId_4841  SubscriptionId_3829
# 2    TransactionId_26203   BatchId_53941  AccountId_4229   SubscriptionId_222
# 3      TransactionId_380  BatchId_102363   AccountId_648  SubscriptionId_2185
# 4    TransactionId_28195   BatchId_38780  AccountId_4841  SubscriptionId_3829
# 5    TransactionId_23223   BatchId_25954  AccountId_1078  SubscriptionId_4238
# 6   TransactionId_118063  BatchId_118460  AccountId_2442  SubscriptionId_1980
# 7   TransactionId_100640   BatchId_38561  AccountId_4841  SubscriptionId_3829
# 8    TransactionId_51905   BatchId_93774   AccountId_272  SubscriptionId_4731
# 9   TransactionId_130161   BatchId_82409   AccountId_710   SubscriptionId_920
# 10   TransactionId_51800  BatchId_112288  AccountId_2634  SubscriptionId_3511
# ...

# %%
# View the last few rows of the DataFrame
data.tail(10)
# Out:
#               TransactionId         BatchId       AccountId  \
# 95652   TransactionId_71994   BatchId_66957   AccountId_620
# 95653   TransactionId_68851  BatchId_100900  AccountId_4841
# 95654   TransactionId_18130   BatchId_20310   AccountId_620
# 95655   TransactionId_38907   BatchId_92168  AccountId_4841
# 95656   TransactionId_68402   BatchId_17092  AccountId_2659
# 95657   TransactionId_89881   BatchId_96668  AccountId_4841
# 95658   TransactionId_91597    BatchId_3503  AccountId_3439
# 95659   TransactionId_82501  BatchId_118602  AccountId_4841
# 95660  TransactionId_136354   BatchId_70924  AccountId_1346
# 95661   TransactionId_35670   BatchId_29317  AccountId_4841
#
#             SubscriptionId       CustomerId CurrencyCode  CountryCode  \
# 95652  SubscriptionId_1833   CustomerId_960          UGX          256
# 95653  SubscriptionId_3829   CustomerId_539          UGX          256
# 95654  SubscriptionId_1833   CustomerId_960          UGX          256
# ...

# %%
data.info() # Get information about the DataFrame, including data types and missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95662 entries, 0 to 95661
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   TransactionId         95662 non-null  object
#  1   BatchId               95662 non-null  object
#  2   AccountId             95662 non-null  object
#  3   SubscriptionId        95662 non-null  object
#  4   CustomerId            95662 non-null  object
#  5   CurrencyCode          95662 non-null  object
#  6   CountryCode           95662 non-null  int64
#  7   ProviderId            95662 non-null  object
#  8   ProductId             95662 non-null  object
#  9   ProductCategory       95662 non-null  object
#  10  ChannelId             95662 non-null  object
#  11  Amount                95662 non-null  float64
#  12  Value                 95662 non-null  int64
#  13  TransactionStartTime  95662 non-null  object
#  14  PricingStrategy       95662 non-null  int64
# ...

# %%
data.shape
# Out:
# (95662, 16)

# %%
data.dtypes.value_counts()
# Out:
# object     11
# int64       4
# float64     1
# Name: count, dtype: int64

# %%
data['CurrencyCode'].value_counts()
# Out:
# CurrencyCode
# UGX    95662
# Name: count, dtype: int64

# %%
data.isnull().sum()
# Out:
# TransactionId           0
# BatchId                 0
# AccountId               0
# SubscriptionId          0
# CustomerId              0
# CurrencyCode            0
# CountryCode             0
# ProviderId              0
# ProductId               0
# ProductCategory         0
# ChannelId               0
# Amount                  0
# Value                   0
# TransactionStartTime    0
# PricingStrategy         0
# FraudResult             0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isna().sum()
# Out:
# TransactionId           0
# BatchId                 0
# AccountId               0
# SubscriptionId          0
# CustomerId              0
# CurrencyCode            0
# CountryCode             0
# ProviderId              0
# ProductId               0
# ProductCategory         0
# ChannelId               0
# Amount                  0
# Value                   0
# TransactionStartTime    0
# PricingStrategy         0
# FraudResult             0
# dtype: int64

# %% [markdown]
# # Summary Statistics for numerical value.

# %%
#Understand the central tendency, dispersion, and shape of the dataset’s distribution.

# %%
# Summary statistics for numerical columns
num = data.describe()
num
# Out:
#        CountryCode        Amount         Value  PricingStrategy   FraudResult
# count      95662.0  9.566200e+04  9.566200e+04     95662.000000  95662.000000
# mean         256.0  6.717846e+03  9.900584e+03         2.255974      0.002018
# std            0.0  1.233068e+05  1.231221e+05         0.732924      0.044872
# min          256.0 -1.000000e+06  2.000000e+00         0.000000      0.000000
# 25%          256.0 -5.000000e+01  2.750000e+02         2.000000      0.000000
# 50%          256.0  1.000000e+03  1.000000e+03         2.000000      0.000000
# 75%          256.0  2.800000e+03  5.000000e+03         2.000000      0.000000
# max          256.0  9.880000e+06  9.880000e+06         4.000000      1.000000

# %%
data.describe(include = 'all')
# Out:
#               TransactionId        BatchId       AccountId  \
# count                 95662          95662           95662
# unique                95662          94809            3633
# top     TransactionId_76871  BatchId_67019  AccountId_4841
# freq                      1             28           30893
# mean                    NaN            NaN             NaN
# std                     NaN            NaN             NaN
# min                     NaN            NaN             NaN
# 25%                     NaN            NaN             NaN
# 50%                     NaN            NaN             NaN
# 75%                     NaN            NaN             NaN
# max                     NaN            NaN             NaN
#
#              SubscriptionId       CustomerId CurrencyCode  CountryCode  \
# count                 95662            95662        95662      95662.0
# unique                 3627             3742            1          NaN
# ...

# %%
 cat = data.describe(include = 'object')

# %%
cat.describe()
# Out:
#         TransactionId  BatchId  AccountId  SubscriptionId  CustomerId  \
# count               4        4          4               4           4
# unique              3        4          4               4           4
# top             95662    95662      95662           95662       95662
# freq                2        1          1               1           1
#
#         CurrencyCode  ProviderId  ProductId  ProductCategory  ChannelId  \
# count              4           4          4                4          4
# unique             3           4          4                4          4
# top            95662       95662      95662            95662      95662
# freq               2           1          1                1          1
#
#         TransactionStartTime
# count                      4
# unique                     4
# top                    95662
# freq                       1

# %%
num.var()
# Out:
# CountryCode        1.138669e+09
# Amount             1.260944e+13
# Value              1.212140e+13
# PricingStrategy    1.143858e+09
# FraudResult        1.143899e+09
# dtype: float64

# %%
range_values = num.max() - num.min()
print("range:")
print(range_values)
# Out:
# range:
# CountryCode           95662.0
# Amount             10880000.0
# Value               9879998.0
# PricingStrategy       95662.0
# FraudResult           95662.0
# dtype: float64

# %%
std_deviation_values = num.std()
print("Standard Deviation:")
print(std_deviation_values)
# Out:
# Standard Deviation:
# CountryCode        3.374416e+04
# Amount             3.550977e+06
# Value              3.481580e+06
# PricingStrategy    3.382097e+04
# FraudResult        3.382157e+04
# dtype: float64

# %%
#shape of the distribution of a dataset, we look at measures such as skewness and kurtosis. 

#Skewness: Skewness measures the asymmetry of the distribution.
#Kurtosis: Kurtosis measures the heaviness of the tails of the distribution.

# %%
skewness = num.skew()
kurtosis = num.kurtosis()

# %%
print("Skewness:")
print(skewness)
print("\nKurtosis:")
print(kurtosis)
# Out:
# Skewness:
# CountryCode        2.828387
# Amount             2.765528
# Value              2.827328
# PricingStrategy    2.828427
# FraudResult        2.828427
# dtype: float64
#
# Kurtosis:
# CountryCode        7.999831
# Amount             7.754442
# Value              7.995311
# PricingStrategy    8.000000
# FraudResult        8.000000
# dtype: float64

# %% [markdown]
# # Distribution of Numerical Features

# %%
#Visualize the distribution of numerical features to identify patterns, skewness, and potential outliers.

# %%
numerical_columns = data.select_dtypes(include=['int', 'float'])

# %%
# Plot histograms for numerical features
for column in numerical_columns.columns:
    
    sns.histplot(data=numerical_columns[column], kde=True)
    
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# Plot box plots for numerical features
for column in numerical_columns.columns:
    
    sns.boxplot(x=numerical_columns[column])
    
    plt.xlabel(column)
    plt.show()

# %%
# Plot density plots for numerical features
for column in numerical_columns.columns:
    
    sns.kdeplot(data=numerical_columns[column], shade=True)
    
    plt.xlabel(column)
    plt.ylabel('Density')
    plt.show()
# Out:
# /var/folders/wt/lvnnhxz92f9c0rx_ldqczjth0000gn/T/ipykernel_84066/3963107699.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=numerical_columns[column], shade=True)
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /var/folders/wt/lvnnhxz92f9c0rx_ldqczjth0000gn/T/ipykernel_84066/3963107699.py:4: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=numerical_columns[column], shade=True)
# /var/folders/wt/lvnnhxz92f9c0rx_ldqczjth0000gn/T/ipykernel_84066/3963107699.py:4: FutureWarning:
#
# ...

# %% [markdown]
# # Distribution of Categorical Features

# %%
#Analyzing the distribution of categorical features provides insights into the frequency and variability of categories.

# %%
categorical_columns = data.select_dtypes(include=['object'])

# %%
for column in categorical_columns.columns:
    plt.figure(figsize=(10, 6))
    sns.countplot(x=column, data=categorical_columns, palette="Set3")
    plt.xlabel(column)
    plt.ylabel('Count')
    plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
    plt.show()

# %%
for column in categorical_columns.columns:
    print(f"\nFrequency counts of {column}:")
    print(cat[column].value_counts())
# Out:
# Frequency counts of TransactionId:
# TransactionId
# 95662                  2
# TransactionId_76871    1
# 1                      1
# Name: count, dtype: int64
#
# Frequency counts of BatchId:
# BatchId
# 95662            1
# 94809            1
# BatchId_67019    1
# 28               1
# Name: count, dtype: int64
#
# Frequency counts of AccountId:
# AccountId
# 95662             1
# 3633              1
# AccountId_4841    1
# 30893             1
# Name: count, dtype: int64
#
# Frequency counts of SubscriptionId:
# SubscriptionId
# 95662                  1
# 3627                   1
# SubscriptionId_3829    1
# 32630                  1
# Name: count, dtype: int64
#
# Frequency counts of CustomerId:
# CustomerId
# 95662              1
# 3742               1
# CustomerId_7343    1
# 4091               1
# Name: count, dtype: int64
#
# Frequency counts of CurrencyCode:
# CurrencyCode
# 95662    2
# 1        1
# UGX      1
# Name: count, dtype: int64
#
# Frequency counts of ProviderId:
# ...

# %% [markdown]
# # Correlation Analysis

# %%
#Understanding the relationship between numerical features.

# %%
corr_matrix = num.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
sns.scatterplot(data='num')
plt.show()

# %%
sns.pairplot(num)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# # Identifying Missing Values

# %%
#Identify missing values to determine missing data and decide on appropriate imputation strategies.

# %%
data.isnull().sum()
# Out:
# TransactionId           0
# BatchId                 0
# AccountId               0
# SubscriptionId          0
# CustomerId              0
# CurrencyCode            0
# CountryCode             0
# ProviderId              0
# ProductId               0
# ProductCategory         0
# ChannelId               0
# Amount                  0
# Value                   0
# TransactionStartTime    0
# PricingStrategy         0
# FraudResult             0
# dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(data.isnull(), cbar=False)
plt.title('Missing Values Heatmap')
plt.show()

# %%
# Fill missing values with the mean of each column
data_filled = num.fillna(num.mean())
# Now df_filled contains the original DataFrame with missing values filled with the mean of each column
num.describe(include = 'all')
# Out:
#         CountryCode        Amount         Value  PricingStrategy   FraudResult
# count      8.000000  8.000000e+00  8.000000e+00         8.000000      8.000000
# mean   12149.750000  1.138680e+06  1.264370e+06     11959.373612  11957.880861
# std    33744.163642  3.550977e+06  3.481580e+06     33820.968433  33821.571577
# min        0.000000 -1.000000e+06  2.000000e+00         0.000000      0.000000
# 25%      256.000000  7.375000e+02  8.187500e+02         1.683231      0.000000
# 50%      256.000000  4.758923e+03  7.450292e+03         2.000000      0.001009
# 75%      256.000000  1.025732e+05  1.025270e+05         2.691981      0.283654
# max    95662.000000  9.880000e+06  9.880000e+06     95662.000000  95662.000000

# %% [markdown]
# # Outlier Detection

# %%
#Use box plots to identify outliers.

# %%
plt.figure(figsize=(10,12))
data.boxplot()
plt.xticks(rotation=45)
plt.show()
